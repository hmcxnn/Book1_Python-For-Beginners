# %% [markdown]
# Chapter 08
# # 用assert检查条件是否为真
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
# 定义除法函数
def divide(a, b):
    assert b != 0, "除数不能为零"
    return a / b

# %%
# 调用自定义函数
result = divide(10, 0)  
# 除以零，会引发 AssertionError 异常
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 调用自定义函数
# ----> 2 result = divide(10, 0)
#       3 # 除以零，会引发 AssertionError 异常
#
# Cell In[1], line 3, in divide(a, b)
#       2 def divide(a, b):
# ----> 3     assert b != 0, "除数不能为零"
#       4     return a / b
#
# AssertionError: 除数不能为零

# %%
print(result)  
# 上行不会被执行，因为异常已经引发
