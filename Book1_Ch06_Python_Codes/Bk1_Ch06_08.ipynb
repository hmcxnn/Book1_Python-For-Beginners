# %% [markdown]
# Chapter 06
# # 利用math.sin() 计算数列列表正弦值并可视化
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
# 导入包
import math
import matplotlib.pyplot as plt

# %%
# 计算正弦值
x_start = 0 # 弧度值
print(math.sin(x_start))
# Out:
# 0.0

# %%
x_end   = 2*math.pi # 弧度值
print(math.sin(x_end))
# Out:
# -2.4492935982947064e-16

# %%
# 等差数列 a_n = a_1 + d(n – 1)
# 数列元素数量
num     = 60
# 计算公差
step = (x_end - x_start) / (num - 1)

# %%
# 生成等差数列列表
x_array = [x_start + i * step for i in range(num)]
x_array
# Out:
# [0.0,
#  0.10649466622338281,
#  0.21298933244676563,
#  0.31948399867014843,
#  0.42597866489353126,
#  0.5324733311169141,
#  0.6389679973402969,
#  0.7454626635636797,
#  0.8519573297870625,
#  0.9584519960104453,
#  1.0649466622338282,
#  1.171441328457211,
#  1.2779359946805937,
#  1.3844306609039765,
#  1.4909253271273595,
#  1.5974199933507423,
#  1.703914659574125,
#  1.8104093257975078,
#  1.9169039920208906,
#  2.0233986582442736,
#  2.1298933244676563,
#  2.236387990691039,
#  2.342882656914422,
#  2.4493773231378047,
#  2.5558719893611874,
#  2.66236665558457,
#  2.768861321807953,
#  2.875355988031336,
#  2.981850654254719,
#  3.0883453204781017,
#  3.1948399867014845,
#  3.3013346529248673,
#  3.40782931914825,
#  3.514323985371633,
#  3.6208186515950156,
#  3.7273133178183984,
#  3.833807984041781,
#  3.940302650265164,
#  4.046797316488547,
#  4.15329198271193,
#  4.259786648935313,
#  4.366281315158695,
#  4.472775981382078,
#  4.579270647605461,
#  4.685765313828844,
#  4.7922599800522265,
#  4.898754646275609,
#  5.005249312498992,
#  5.111743978722375,
#  5.218238644945758,
#  5.32473331116914,
#  5.431227977392523,
#  5.537722643615906,
#  5.644217309839289,
#  5.750711976062672,
#  5.857206642286055,
#  5.963701308509438,
#  6.070195974732821,
#  6.1766906409562035,
#  6.283185307179586]

# %%
# 生成等长全0列表,等价于zero_array = [0] * len(x_array)
zero_array = [0 for i in range(num)]

# %%
# 可视化等差数列
plt.plot(x_array, zero_array, marker = '.',
         markersize = 8,
         markerfacecolor="w",
         markeredgecolor='k')
plt.text(x_start, 0, '0')
plt.text(x_end,   0, r'$2\pi$')
plt.axis('off')
plt.show()

# %%
# 正弦 sin(x) 列表
y_array = [math.sin(x_idx) for x_idx in x_array]
y_array
# Out:
# [0.0,
#  0.1062934856473654,
#  0.21138262362962432,
#  0.31407671202194876,
#  0.41321218576837815,
#  0.5076658003388399,
#  0.5963673585385013,
#  0.6783118362696161,
#  0.7525707698561385,
#  0.818302775908169,
#  0.8747630845319613,
#  0.921311977870413,
#  0.9574220383620055,
#  0.9826841245925209,
#  0.9968120070307501,
#  0.9996456111234526,
#  0.9911528310040072,
#  0.97142989326471,
#  0.9407002666710333,
#  0.8993121301712192,
#  0.847734427889671,
#  0.7865515558026426,
#  0.7164567402983153,
#  0.6382441836448203,
#  0.5528000653611936,
#  0.4610925014493262,
#  0.3641605752528225,
#  0.26310256422752126,
#  0.1590634960190721,
#  0.053222174842178754,
#  -0.053222174842178505,
#  -0.15906349601907185,
#  -0.26310256422752104,
#  -0.3641605752528219,
#  -0.46109250144932556,
#  -0.5528000653611931,
#  -0.6382441836448197,
#  -0.7164567402983149,
#  -0.7865515558026425,
#  -0.8477344278896709,
#  -0.8993121301712191,
#  -0.9407002666710332,
#  -0.9714298932647099,
#  -0.9911528310040071,
#  -0.9996456111234525,
#  -0.9968120070307502,
#  -0.9826841245925211,
#  -0.9574220383620057,
#  -0.9213119778704132,
#  -0.8747630845319616,
#  -0.8183027759081695,
#  -0.752570769856139,
#  -0.6783118362696167,
#  -0.5963673585385021,
#  -0.5076658003388399,
#  -0.4132121857683782,
#  -0.3140767120219489,
#  -0.21138262362962446,
#  -0.1062934856473656,
#  -2.4492935982947064e-16]

# %%
# 可视化正弦函数
plt.plot(x_array, y_array, marker = '.',
         markersize = 8,
         markerfacecolor="w",
         markeredgecolor='k')
plt.text(x_start, -0.1, '0')
plt.text(x_end,    0.1, r'$2\pi$')
plt.axhline(y=0, color='k', linestyle='--', linewidth=0.25)
plt.axis('off') 
plt.show()

# %%
import numpy as np
x_array_2 = np.linspace(0,2*np.pi,60)
y_array_2 = np.sin(x_array_2)
plt.plot(x_array_2,y_array_2,marker='.',markersize=10)
plt.axhline(y=0,color='k',linestyle='--',linewidth=0.25)
plt.axis('off')
plt.show()
