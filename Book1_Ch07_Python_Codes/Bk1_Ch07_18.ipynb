# %% [markdown]
# Chapter 07
# # 列表生成式
# Book_1《编程不难》 | 鸢尾花书：从加减乘除到机器学习

# %%
# 使用列表生成式，获得1 ~ 10之间所有偶数列表
even_numbers = [num for num in range(1, 11)  
                if num % 2 == 0] # 一行放不下

print(even_numbers) # Output: [2, 4, 6, 8, 10]
# Out:
# [2, 4, 6, 8, 10]

# %%
# 嵌套列表生成式
matrix = [[i * j for j in range(1, 4)] 
                 for i in range(1, 4)]## for i 先生成, 然后生成j
print(matrix) 
# Output: [[1, 2, 3], [2, 4, 6], [3, 6, 9]]
# Out:
# [[1, 2, 3], [2, 4, 6], [3, 6, 9]]

# %%
maxtrix_2 = [[i*j for j in range(1,4)] for i in range(5,8)]
print(maxtrix_2)
# Out:
# [[5, 10, 15], [6, 12, 18], [7, 14, 21]]
